# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/paulotguerra/QXD0178/blob/main/00.01-Introducao-Mineracao-de-Dados.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## QXD0178 - Mineração de Dados
# # Dados, informação e conhecimento

# %% [markdown]
# **Professor:** Paulo de Tarso Guerra Oliveira ([paulodetarso@ufc.br](mailto:paulodetarso@ufc.br))
#
# Parcialmente adaptado de: [*Introdução à Mineração de Dados: Conceitos Básicos, Algoritmos e Aplicações.*](https://app.minhabiblioteca.com.br/reader/books/978-85-472-0100-5/pageid/45)

# %% [markdown]
# # Conceitos básicos

# %% [markdown]
# * O **dado** é um fato, um valor documentado ou um resultado de medição.
# * Quando um significado é atribuído aos dados, gera-se uma **informação**.
# * Quando um agente se torna consciente destes significados e torna-se capaz de tomar decisões a partir destes, temos o **conhecimento**.

# %% [markdown]
# Dados existem em diferentes formas:

# %% [markdown]
# **Dados não-estruturados**: dado não estruturado é aquele que não possui um modelo de dados, que não está organizado de uma maneira predefinida ou que não reside em locais definidos.
#
# ```
# A Mineração de Dados surgiu como área de pesquisa e aplicação independente em meados da década de 1990, mas suas origens na matemática, estatística e computação são muito anteriores a esse período. A área também ganhou evidência nos últimos anos após ser cunhado o termo Big Data e com a publicação do relatório intitulado ?Big Data: The Next Frontier for Innovation, Competition, and Productivity? pelo McKinsey Global Institute em meados de 2011.|
# ```

# %% [markdown]
# **Dados semi-estruturados**: o dado semiestruturado é um tipo de dado que não possui a estrutura completa de um modelo de dados, mas também não é totalmente desestruturado.
#
# ```json
# {
#     "_id": 1,
#     "title": "Unlocking Android",
#     "isbn": "1933988673",
#     "pageCount": 416,
#     "thumbnailUrl": "https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ.book-thumb-images/ableson.jpg",
#     "shortDescription": "Unlocking Android: A Developer's Guide provides concise, hands-on instruction for the Android operating system and development tools. This book teaches important architectural concepts in a straightforward writing style and builds on this with practical and useful examples throughout.",
#     "authors": ["W. Frank Ableson", "Charlie Collins", "Robi Sen"],
# } {
#     "_id": 2,
#     "title": "Android in Action, Second Edition",
#     "authors": ["W. Frank Ableson", "Robi Sen"],
#     "isbn": "1935182722",
#     "status": "PUBLISH",
#     "categories": ["Java"],
#     "pageCount": 592,
# }
# ```

# %% [markdown]
# **Dados estruturados:** dados descritos em campos fixos - por exemplo, uma tabela, uma planilha ou um banco de dados - de acordo com um *modelo de dados*, isto é, a descrição dos objetos juntamente com suas propriedades e relações.

# %%
import numpy as np
import pandas as pd

# Base de dados presente no livro
df = pd.DataFrame({ 'Nome':["Roberto Felix","Joana Pereira",np.nan,"Isabela Assis","Marco Araújo"],
                    'Idade':[42,10,np.nan,33,29],
                    'Nível Educacional':["Especialização","Doutorado",np.nan,"Graduação","Graduação"],
                    'Gênero':['M','F',np.nan,'F','M'],
                    'Cartão de Crédito':['Sim','Sim',np.nan,np.nan,'Não'],
                    'Renda mensal (R$)':[5000,6500,np.nan,3900,3100]})

# %%
df # Mostra o dataframe
# Out:
#             Nome  Idade Nível Educacional Gênero Cartão de Crédito  \
# 0  Roberto Felix   42.0    Especialização      M               Sim
# 1  Joana Pereira   10.0         Doutorado      F               Sim
# 2            NaN    NaN               NaN    NaN               NaN
# 3  Isabela Assis   33.0         Graduação      F               NaN
# 4   Marco Araújo   29.0         Graduação      M               Não
#
#    Renda mensal (R$)
# 0             5000.0
# 1             6500.0
# 2                NaN
# 3             3900.0
# 4             3100.0

# %% [markdown]
# No caso de dados estruturados, cada **linha** da tabela de dados geralmente corresponde a um **objeto**, uma **instância**, um exemplo, um registro, um vetor de entradas ou padrão (de entrada ou treinamento).

# %% [markdown]
# Cada **coluna**, por sua vez, corresponde a um **atributo**, uma **característica**(*features*) ou uma variável.
#
# * Atributo dependente *vs.* atributo independente
# * Atributo numérico *vs.* atributo categórico

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Níveis de medida de atributos:
#
# * **Binário**: pode assumir apenas dois valores possíveis, por exemplo 0 ou 1;
# * **Nominal**: pode possuir símbolos ou rótulos distintos, por exemplo "estado civil" pode assumir os valores "solteiro", "casado", etc;
# * **Ordinal**: permite ordenar suas categorias, embora não necessariamente haja uma noção explícita de distância entre as categorias. Por exemplo: o atributo "nível educacional" pode assumir os valores "fundamental", "médio", "graduação", "mestrado", etc;
# * **Razão**: quantidades para as quais o método de medida define o ponto zero, por exemplo a distância entre dois objetos, salário, etc.

# %% [markdown]
# ### Problemas nos dados

# %% [markdown]
# O objetivo das técnicas de pré-processamento de dados é preparar os dados brutos para serem analisados de modo mais eficiente.

# %% [markdown]
# Para a maioria das bases de dados reais, a etapa de pré-processamento demandam bastante trabalho e consomem muito tempo, mas o sucesso da mineração depende fortemente do cuidado dedicado a essa etapa.

# %% [markdown]
# Tipos de problemas nos dados:

# %% [markdown]
# **Incompletude**: em uma base de dados pode faltar valores de um dado atributo ("célula"), pode faltar um atributo de interesse ("coluna") ou pode faltar um objeto de interesse ("linha").

# %% [markdown]
# **Inconsistência**: um dado inconsistente normalmente é aquele cujo valor está fora do domínio do atributo ou apresenta uma grande discrepância em rela-ção aos outros dados.

# %% [markdown]
# **Ruído**: Um dado ruidoso é aquele que apresenta alguma variação em relação ao seu valor sem ruído e, portanto, podem levar a inconsistências na base de dados.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Conhecer e preparar de forma adequada os dados para análise é uma etapa chamada de pré-processamento de dados e que pode tornar todo o processo de mineração muito mais eficiente e eficaz.

# %%
df
# Out:
#             Nome  Idade Nível Educacional Gênero Cartão de Crédito  \
# 0  Roberto Felix   42.0    Especialização      M               Sim
# 1  Joana Pereira   10.0         Doutorado      F               Sim
# 2            NaN    NaN               NaN    NaN               NaN
# 3  Isabela Assis   33.0         Graduação      F               NaN
# 4   Marco Araújo   29.0         Graduação      M               Não
#
#    Renda mensal (R$)
# 0             5000.0
# 1             6500.0
# 2                NaN
# 3             3900.0
# 4             3100.0

# %%
mask = df.notnull().any(axis='columns')
mask
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# dtype: bool

# %% [markdown]
# Para fazer uso efetivo da mineração, é preciso pensar em algumas questões importantes antes de iniciar a análise:
#
# * Existem dados ausentes, inconsistentes ou ruidosos? Como tratá-los?
# * Quais são os tipos de atributos da base? É preciso padronizá-los?
# * É possível resumir a base de dados?
# * Há atributos naturalmente inter-relacionados?
# * Existem atributos que são mais relevantes que outros?
# * Existem atributos irrelevantes?

# %% [markdown]
# ### Exemplo - [Food choices: College students' food and cooking preferences](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv)

# %% [markdown]
# Esta base de dados inclui informações sobre escolhas alimentares, nutrição, preferências, favoritos da infância e outras informações de estudantes universitários. Existem 126 respostas de alunos. Os dados são brutos e não limpos.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/She-Codes-Now/Intro-to-Data-Science-with-R/master/food_coded.csv")
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %% [markdown]
# Algumas bases de dados possuem [documentos](https://www.kaggle.com/datasets/borapajo/food-choices?select=codebook_food.docx) que descrevem detalhes seus tipos e categorias.

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# type_sports                     21
# calories_day                    19
# comfort_food_reasons_coded      19
# cuisine                         17
# exercise                        13
#                                 ..
# comfort_food_reasons_coded.1     0
# diet_current_coded               0
# ethnic_food                      0
# eating_out                       0
# fruit_day                        0
# Length: 61, dtype: int64

# %% [markdown]
# ##  Processo de preparação da base de dados

# %% [markdown]
# **1. Limpeza de dados**
#
# O primeiro passo é verificar se a base necessita de algum procedimento de limpeza de dados.
#
# Alguns objetos podem ter informações faltantes. Uma das opções é eliminar esses objetos, reduzindo o tamanho da base; contudo, a remoção pode causar perda de informação importante.

# %% [markdown]
# **2. Redução dos dados**
#
# A redução dos dados tem como um dos objetivos a construção de bases de dados menores para aumento do desempenho computacional, ao mesmo tempo que tenta manter as características originais dos dados.

# %% [markdown]
# **3. Transformação**
#
# Os métodos de transformação de dados visam modificar ou consolidar os dados em formas apro-priadas aos processos de mineração.
#
# Por exemplo, pode haver valores de um mesmo atributo escritos em maiúsculo e outros em minúsculo, e os formatos e as unidades podem ser diferentes.
#
# Problemas dessa natureza são resolvidos padronizando ou normalizando os dados.

# %% [markdown]
# **4. Discretização**
#
# Muitos algoritmos em mineração de dados não trabalham com dados mistos, ou seja, bases de dados com atributos categóricos e contínuos.
#
# Nesses casos, atributos numéricos podem ser discretizados, dividindo o domínio do atributo em intervalos e ampliando a quanti-dade de métodos de análise disponíveis para aplicação.
